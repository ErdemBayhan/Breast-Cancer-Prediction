# %%
import pandas as pd
df = pd.read_csv('breast_cancer_dataset.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# DATA EXPLORATION
#
# The Distribution of Target Variable (Bening and Malignant)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("\nTarget Variable Distribution:")
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis', data=df, palette='plasma')
plt.title('Distribution of The Target Variable (Benign vs. Malignant)')
plt.show()
# Out:
# Target Variable Distribution:
# <ipython-input-19-3d8e9054f8b5>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=df, palette='plasma')

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (569, 32)

# %%
df.drop('id', axis=1, inplace=True)

# %%
# Convert 'diagnosis' to numerical
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})
df['diagnosis'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# Numerical Feautures Statistics

# %%
df.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# Visualization of Outliers with Boxplot and Histogram Graphs

# %%
numerical_features = df.select_dtypes(include=['float64', 'int64']).drop(columns=['diagnosis'], errors='ignore')

plt.figure(figsize=(20, 20))
for i, feature in enumerate(numerical_features):
    plt.subplot(6, 6, i + 1)
    sns.boxplot(x='diagnosis', y=feature, data=df)
    plt.title(f'{feature} vs. Diagnosis')
plt.tight_layout()
plt.show()

# %%
numerical_features = df.select_dtypes(include=['float64', 'int64']).drop(columns=['diagnosis'], errors='ignore')

plt.figure(figsize=(20, 20))
for i, feature  in enumerate(numerical_features.columns):
    plt.subplot(6, 6, i + 1)
    sns.histplot(df[feature], kde=True, color = 'Blue')
    plt.title(feature, fontsize=10)
    plt.xlabel('')
    plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Winsorizing the Dataset according to outliers

# %%
from scipy.stats.mstats import winsorize

df_winsorized = df.copy() #To keep the original dataset

numerical_features = df.select_dtypes(include=['float64', 'int64']).drop(columns=['diagnosis'], errors='ignore')

for col in numerical_features:
    if col in df_winsorized.columns and pd.api.types.is_numeric_dtype(df_winsorized[col]):
          if col != 'diagnosis':
                df_winsorized[col] = df_winsorized[col].clip(lower=df_winsorized[col].quantile(0.05), upper=df_winsorized[col].quantile(0.95) )

cols_to_compare = ['area_mean', 'compactness_mean', 'area_worst'] #Comparing to dataset after winsorizing
print("\n--- Original Dataset Statistics ---")
print(df[cols_to_compare].describe())
print("\n--- After winsorizing Dataset Statistics ---")
print(df_winsorized[cols_to_compare].describe())
# Out:
# --- Original Dataset Statistics ---
#          area_mean  compactness_mean   area_worst
# count   569.000000        569.000000   569.000000
# mean    654.889104          0.104341   880.583128
# std     351.914129          0.052813   569.356993
# min     143.500000          0.019380   185.200000
# 25%     420.300000          0.064920   515.300000
# 50%     551.100000          0.092630   686.500000
# 75%     782.700000          0.130400  1084.000000
# max    2501.000000          0.345400  4254.000000
#
# --- After winsorizing Dataset Statistics ---
#          area_mean  compactness_mean   area_worst
# count   569.000000        569.000000   569.000000
# mean    641.096696          0.102700   856.307452
# std     300.779265          0.047075   482.285494
# min     275.780000          0.040660   331.060000
# 25%     420.300000          0.064920   515.300000
# 50%     551.100000          0.092630   686.500000
# 75%     782.700000          0.130400  1084.000000
# ...

# %% [markdown]
# After winsorizing the dataset, now we can see the outliers again with box plot and histogram graphs

# %%
numerical_features = df_winsorized.select_dtypes(include=['float64', 'int64']).drop(columns=['diagnosis'], errors='ignore')

plt.figure(figsize=(20, 20))
for i, feature in enumerate(numerical_features):
    plt.subplot(6, 6, i + 1)
    sns.boxplot(x='diagnosis', y=feature, data=df_winsorized)
    plt.title(f'{feature} vs. Diagnosis')
plt.tight_layout()
plt.savefig('a.png')
plt.show()

# %%
numerical_features = df_winsorized.select_dtypes(include=['float64', 'int64']).drop(columns=['diagnosis'], errors='ignore')

plt.figure(figsize=(20, 20))
for i, feature  in enumerate(numerical_features.columns):
    plt.subplot(6, 6, i + 1)
    sns.histplot(df_winsorized[feature], kde=True, color = 'Blue')
    plt.title(feature, fontsize=10)
    plt.xlabel('')
    plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
len(df.columns)
# Out:
# 31

# %% [markdown]
# Correlation Heatmap to see how many features correlate togetger and we can see the most and least correlated features here.

# %%
plt.figure(figsize=(20, 20))
correlation_matrix = df_winsorized.corr('pearson')
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Assinging the 'diagnosis' column as the target variable. As seen the above, df_winsorized dataset assigned.

# %%
# Assign the 'diagnosis' column as the target variable (y)
y = df_winsorized['diagnosis']

# Assign all other columns as features (X)
X = df_winsorized.drop('diagnosis', axis=1)

print("\nFirst 5 rows of target variable (y):")
print(y.head())
print("\nFirst 5 rows of features (X):")
display(X.head())
# Out:
# First 5 rows of target variable (y):
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64
#
# First 5 rows of features (X):
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99        13.088          122.80     1001.0          0.11840
# 1        20.57        17.770          132.90     1309.8          0.08474
# 2        19.69        21.250          130.00     1203.0          0.10960
# 3        11.42        20.380           77.58      386.1          0.11878
# 4        20.29        14.340          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.20870         0.24302              0.12574        0.23072
# 1           0.07864         0.08690              0.07017        0.18120
# 2           0.15990         0.19740              0.12574        0.20690
# 3           0.20870         0.24140              0.10520        0.23072
# ...

# %% [markdown]
# After checking the missing values in dataset, there is no missing values in this dataset. So we do not need to immutate.

# %%
# Check for missing values in the DataFrame
miss_values = df.isnull().sum()

print("\nMissing Values per Column:")
print(miss_values)
# Out:
# Missing Values per Column:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# Using a StandartScaler to numerical features share a similar range.

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

num_features_for_scaling = X.select_dtypes(include=np.number).columns
scaler = StandardScaler()
X[num_features_for_scaling] = scaler.fit_transform(X[num_features_for_scaling])
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.239060     -1.574261        1.446102   1.197622         1.794426
# 1     2.051465     -0.371913        1.910634   2.225192        -0.914224
# 2     1.774366      0.521759        1.777253   1.869802         1.086282
# 3    -0.829739      0.298341       -0.633714  -0.848533         1.825005
# 4     1.963297     -1.252745        2.011819   2.182599         0.337903
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          2.253707        2.250776             2.227656       2.094452
# 1         -0.511555        0.018428             0.640089       0.026126
# 2          1.216149        1.598459             2.227656       1.099551
# 3          2.253707        2.227612             1.640853       2.094452
# 4          0.639964        1.607039             1.615141       0.013596
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# Spilit to Dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Training set shape (X_train): {X_train.shape}")
print(f"Testing set shape (X_test): {X_test.shape}")
print(f"Training target shape (y_train): {y_train.shape}")
print(f"Testing target shape (y_test): {y_test.shape}")
# Out:
# Training set shape (X_train): (398, 30)
# Testing set shape (X_test): (171, 30)
# Training target shape (y_train): (398,)
# Testing target shape (y_test): (171,)

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 149    -0.099204     -0.335961       -0.148945  -0.186669        -1.340720
# 124    -0.215712     -0.726300       -0.241851  -0.291489        -1.694631
# 421     0.199937     -1.345194        0.315587   0.049925         0.563222
# 195    -0.360560     -0.741708       -0.406047  -0.414944        -1.343134
# 545    -0.136991      1.030228       -0.191719  -0.225935        -0.292989
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 149         -0.827926       -0.812196            -0.984904      -1.389791
# 124         -0.626155       -0.067079            -0.564657      -1.602806
# 421          1.720045        0.849196             0.435250       1.170555
# 195         -1.042666       -0.670351            -0.685503       0.097131
# 545         -0.749046       -0.798898            -0.666648      -0.592032
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %% [markdown]
# MODELS TRAINING

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression


#SVM
# Convert column names to strings
X_train.columns = X_train.columns.astype(str)

# Initialize the SVM classifier
svm_classifier = SVC(random_state=42)

# Fit the classifier to the training data
svm_classifier.fit(X_train, y_train)

#DECISION TREE

# Initialize the Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Fit the classifier to the training data
dt_classifier.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred_dt = dt_classifier.predict(X_test)

#RANDOM FOREST

# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier(random_state=42)

# Fit the classifier to the training data
rf_classifier.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred_rf = rf_classifier.predict(X_test)

#KNN

# Initialize the KNN classifier
knn_classifier = KNeighborsClassifier() #KNN doesn't have a random_state parameter

# Fit the classifier to the training data
knn_classifier.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred_knn = knn_classifier.predict(X_test)

#LOGISTIC REGRESSION

# Initialize the Logistic Regression classifier
logreg_classifier = LogisticRegression(random_state=42)

# Fit the classifier to the training data
logreg_classifier.fit(X_train, y_train)

# Predict the target variable for the test set
y_pred_logreg = logreg_classifier.predict(X_test)

# %%
print("--- Default Hyperparameters ---")

print("\nLogistic Regression:")
print(logreg_classifier.get_params())

print("\nSupport Vector Machine (SVC):")
print(svm_classifier.get_params())

print("\nDecision Tree Classifier:")
print(dt_classifier.get_params())

print("\nRandom Forest Classifier:")
print(rf_classifier.get_params())

print("\nK-Nearest Neighbors Classifier:")
print(knn_classifier.get_params())
# Out:
# --- Default Hyperparameters ---
#
# Logistic Regression:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': 42, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# Support Vector Machine (SVC):
# {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': 42, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#
# Decision Tree Classifier:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': 42, 'splitter': 'best'}
#
# ...

# %% [markdown]
# MODELS EVALUATION AND VİSUALIZATION

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

#SVM

# Convert column names to strings
X_test.columns = X_test.columns.astype(str)

# Predict the target variable for the test set
y_pred = svm_classifier.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
print(f"AUC-ROC: {auc_roc}")

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix(SVM)")
plt.show()

# Generate classification report
print(classification_report(y_test, y_pred))

#DECISION TREE

# Calculate evaluation metrics
accuracy_dt = accuracy_score(y_test, y_pred_dt)
precision_dt = precision_score(y_test, y_pred_dt)
recall_dt = recall_score(y_test, y_pred_dt)
f1_dt = f1_score(y_test, y_pred_dt)
auc_roc_dt = roc_auc_score(y_test, y_pred_dt)

print(f"Accuracy (Decision Tree): {accuracy_dt}")
print(f"Precision (Decision Tree): {precision_dt}")
print(f"Recall (Decision Tree): {recall_dt}")
print(f"F1-score (Decision Tree): {f1_dt}")
print(f"AUC-ROC (Decision Tree): {auc_roc_dt}")

# Generate confusion matrix
cm_dt = confusion_matrix(y_test, y_pred_dt)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_dt, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Decision Tree)")
plt.show()

# Generate classification report
print(classification_report(y_test, y_pred_dt))

#RANDOM FOREST

# Calculate evaluation metrics
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)
auc_roc_rf = roc_auc_score(y_test, y_pred_rf)

print(f"Accuracy (Random Forest): {accuracy_rf}")
print(f"Precision (Random Forest): {precision_rf}")
print(f"Recall (Random Forest): {recall_rf}")
print(f"F1-score (Random Forest): {f1_rf}")
print(f"AUC-ROC (Random Forest): {auc_roc_rf}")

# Generate confusion matrix
cm_rf = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_rf, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Random Forest)")
plt.show()

# Generate classification report
print(classification_report(y_test, y_pred_rf))

#KNN

# Calculate evaluation metrics
accuracy_knn = accuracy_score(y_test, y_pred_knn)
precision_knn = precision_score(y_test, y_pred_knn)
recall_knn = recall_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn)
auc_roc_knn = roc_auc_score(y_test, y_pred_knn)

print(f"Accuracy (KNN): {accuracy_knn}")
print(f"Precision (KNN): {precision_knn}")
print(f"Recall (KNN): {recall_knn}")
print(f"F1-score (KNN): {f1_knn}")
print(f"AUC-ROC (KNN): {auc_roc_knn}")

# Generate confusion matrix
cm_knn = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_knn, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (KNN)")
plt.show()

# Generate classification report
print(classification_report(y_test, y_pred_knn))

#LOGISTIC REGRESSION


# Calculate evaluation metrics
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
precision_logreg = precision_score(y_test, y_pred_logreg)
recall_logreg = recall_score(y_test, y_pred_logreg)
f1_logreg = f1_score(y_test, y_pred_logreg)
auc_roc_logreg = roc_auc_score(y_test, y_pred_logreg)

print(f"Accuracy (Logistic Regression): {accuracy_logreg}")
print(f"Precision (Logistic Regression): {precision_logreg}")
print(f"Recall (Logistic Regression): {recall_logreg}")
print(f"F1-score (Logistic Regression): {f1_logreg}")
print(f"AUC-ROC (Logistic Regression): {auc_roc_logreg}")

# Generate confusion matrix
cm_logreg = confusion_matrix(y_test, y_pred_logreg)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_logreg, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Logistic Regression)")
plt.show()
# Generate classification report
print(classification_report(y_test, y_pred_logreg))
# Out:
# Accuracy: 0.9766081871345029
# Precision: 0.9682539682539683
# Recall: 0.9682539682539683
# F1-score: 0.9682539682539683
# AUC-ROC: 0.974867724867725
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       108
#            1       0.97      0.97      0.97        63
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171
#
# Accuracy (Decision Tree): 0.935672514619883
# Precision (Decision Tree): 0.90625
# Recall (Decision Tree): 0.9206349206349206
# F1-score (Decision Tree): 0.9133858267716536
# AUC-ROC (Decision Tree): 0.9325396825396824
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       108
#            1       0.91      0.92      0.91        63
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.93      0.93       171
# ...

# %% [markdown]
# Comparison Table

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Make sure X_test columns are strings if necessary, as done before
X_test.columns = X_test.columns.astype(str)

y_pred_svm = svm_classifier.predict(X_test)
y_pred_logreg = logreg_classifier.predict(X_test)
y_pred_dt = dt_classifier.predict(X_test)
y_pred_rf = rf_classifier.predict(X_test)
y_pred_knn = knn_classifier.predict(X_test)


# Calculate metrics for each model
metrics = {}

# SVM Metrics
metrics['SVM'] = {
    'Accuracy': accuracy_score(y_test, y_pred_svm),
    'Precision': precision_score(y_test, y_pred_svm),
    'Recall': recall_score(y_test, y_pred_svm),
    'F1-score': f1_score(y_test, y_pred_svm),
    'AUC-ROC': roc_auc_score(y_test, y_pred_svm)
}

# Logistic Regression Metrics
metrics['Logistic Regression'] = {
    'Accuracy': accuracy_score(y_test, y_pred_logreg),
    'Precision': precision_score(y_test, y_pred_logreg),
    'Recall': recall_score(y_test, y_pred_logreg),
    'F1-score': f1_score(y_test, y_pred_logreg),
    'AUC-ROC': roc_auc_score(y_test, y_pred_logreg)
}

# Decision Tree Metrics
metrics['Decision Tree'] = {
    'Accuracy': accuracy_score(y_test, y_pred_dt),
    'Precision': precision_score(y_test, y_pred_dt),
    'Recall': recall_score(y_test, y_pred_dt),
    'F1-score': f1_score(y_test, y_pred_dt),
    'AUC-ROC': roc_auc_score(y_test, y_pred_dt)
}

# Random Forest Metrics
metrics['Random Forest'] = {
    'Accuracy': accuracy_score(y_test, y_pred_rf),
    'Precision': precision_score(y_test, y_pred_rf),
    'Recall': recall_score(y_test, y_pred_rf),
    'F1-score': f1_score(y_test, y_pred_rf),
    'AUC-ROC': roc_auc_score(y_test, y_pred_rf)
}

# KNN Metrics
metrics['KNN'] = {
    'Accuracy': accuracy_score(y_test, y_pred_knn),
    'Precision': precision_score(y_test, y_pred_knn),
    'Recall': recall_score(y_test, y_pred_knn),
    'F1-score': f1_score(y_test, y_pred_knn),
    'AUC-ROC': roc_auc_score(y_test, y_pred_knn)
}

# Create a Pandas DataFrame from the metrics dictionary
metrics_df = pd.DataFrame(metrics).T # .T transposes the DataFrame for better readability

# Display the comparison table
print("\nModel Performance Comparison:")
display(metrics_df)
# Out:
# Model Performance Comparison:
#                      Accuracy  Precision    Recall  F1-score   AUC-ROC
# SVM                  0.976608   0.968254  0.968254  0.968254  0.974868
# Logistic Regression  0.994152   1.000000  0.984127  0.992000  0.992063
# Decision Tree        0.935673   0.906250  0.920635  0.913386  0.932540
# Random Forest        0.970760   0.983333  0.936508  0.959350  0.963624
# KNN                  0.959064   0.951613  0.936508  0.944000  0.954365

# %% [markdown]
# Fine-Tuning for SVM

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {'C': [0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1, 1], 'kernel': ['linear', 'rbf', 'poly', 'sigmoid']}

# Instantiate GridSearchCV
grid_search = GridSearchCV(SVC(random_state=42, probability=True), param_grid, cv=3, scoring='roc_auc',verbose=1 , n_jobs=1)

# Fit GridSearchCV to the training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and score
print("Best hyperparameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Get the best estimator
best_svm_classifier = grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Best hyperparameters: {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# Best score: 0.99506925661831

# %% [markdown]
# Fine-Tuning for Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

param_grid_logres = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga'],
    'max_iter': [100, 200],
    'fit_intercept': [True, False],
    'tol': [0.0001, 0.001, 0.01, 0.1],
    'dual': [False],
    'warm_start': [True, False],
}


log_grid_search = GridSearchCV(estimator = LogisticRegression(random_state=42),
                              param_grid = param_grid_logres,
                              cv = 3,
                              scoring='roc_auc',
                              n_jobs = -1,
                              verbose = 1,
                              )

print("Grid Search of Logistic Regression")
log_grid_search.fit(X_train, y_train)

print("\nBest Hyperparameters for Logistic Regression:")
print(log_grid_search.best_params_)

print("\nAverage ROC AUC Score of Logistic Regression:")
print(f"{log_grid_search.best_score_:.2f}")

lr_best_model = log_grid_search.best_estimator_

print("\nBest Model for Logistic Regression Found")
# Out:
# Grid Search of Logistic Regression
# Fitting 3 folds for each of 768 candidates, totalling 2304 fits
#
# Best Hyperparameters for Logistic Regression:
# {'C': 1, 'dual': False, 'fit_intercept': False, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear', 'tol': 0.1, 'warm_start': True}
#
# Average ROC AUC Score of Logistic Regression:
# 1.00
#
# Best Model for Logistic Regression Found

# %% [markdown]
# SVM TRAINING WITH BEST HYPERPARAMETERS

# %%
#SVM
# Convert column names to strings
X_train.columns = X_train.columns.astype(str)

# Initialize the SVM classifier with best hyperparameters
best_svm_params ={'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'} # According to GridSearch Best parameters
best_svm_classifier = SVC(random_state=42, **best_svm_params)


# Predict the target variable for the test set using the best SVM model
best_svm_classifier.fit(X_train, y_train)
# Out:
# SVC(C=0.1, gamma=0.001, kernel='linear', random_state=42)

# %% [markdown]
# TUNED SVM EVALUATION

# %%
# Convert column names to strings
X_test.columns = X_test.columns.astype(str)

# Predict the target variable for the test set using the best SVM model
best_pred_svm = best_svm_classifier.predict(X_test)

# Calculate evaluation metrics for the best SVM model
accuracy_best_svm = accuracy_score(y_test, best_pred_svm)
precision_best_svm = precision_score(y_test, best_pred_svm)
recall_best_svm = recall_score(y_test, best_pred_svm)
f1_best_svm = f1_score(y_test, best_pred_svm)
auc_roc_best_svm = roc_auc_score(y_test, best_pred_svm)

print(f"Accuracy (Tuned SVM): {accuracy_best_svm}")
print(f"Precision (Tuned SVM): {precision_best_svm}")
print(f"Recall (Tuned SVM): {recall_best_svm}")
print(f"F1-score (Tuned SVM): {f1_best_svm}")
print(f"AUC-ROC (Tuned SVM): {auc_roc_best_svm}")

# Generate confusion matrix for the best SVM model
cm_best_svm = confusion_matrix(y_test, best_pred_svm)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_best_svm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Tuned SVM)")
plt.show()

# Generate classification report for the best SVM model
print(classification_report(y_test, best_pred_svm))
# Out:
# Accuracy (Tuned SVM): 0.9941520467836257
# Precision (Tuned SVM): 1.0
# Recall (Tuned SVM): 0.9841269841269841
# F1-score (Tuned SVM): 0.992
# AUC-ROC (Tuned SVM): 0.9920634920634921
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       108
#            1       1.00      0.98      0.99        63
#
#     accuracy                           0.99       171
#    macro avg       1.00      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %% [markdown]
# LOGISTIC REGRESSION TRAINING WITH BEST HYPERPARAMETERS

# %%
#LOGISTIC REGRESSION


# Initialize the Logistic Regression classifier with best hyperparameters
#best_logreg_params = {'C': 0.1, 'class_weight': None, 'dual': False, 'fit_intercept': False, 'max_iter': 100, 'n_jobs': 2, 'penalty': 'l2', 'solver': 'liblinear', 'tol': 0.0001, 'warm_start': True} #According to GridSearch Parameters
best_logreg_params = {'C': 1, 'dual': False, 'fit_intercept': False, 'penalty': 'l1', 'solver': 'liblinear', 'tol': 0.1, 'warm_start': True}
best_logreg_classifier = LogisticRegression(random_state=42, **best_logreg_params)


# Fit the classifier to the training data
best_logreg_classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1, fit_intercept=False, penalty='l1', random_state=42,
#                    solver='liblinear', tol=0.1, warm_start=True)

# %% [markdown]
# TUNED LOGISTIC REGRESSION EVALUATION

# %%
# Convert column names to strings
X_test.columns = X_test.columns.astype(str)

# Predict the target variable for the test set using the best SVM model
best_pred_logreg = best_logreg_classifier.predict(X_test)

# Calculate evaluation metrics for the best Logistic Regression model
accuracy_best_logreg = accuracy_score(y_test, best_pred_logreg)
precision_best_logreg = precision_score(y_test, best_pred_logreg)
recall_best_logreg = recall_score(y_test, best_pred_logreg)
f1_best_logreg = f1_score(y_test, best_pred_logreg)
auc_roc_best_logreg = roc_auc_score(y_test, best_pred_logreg)

print(f"Accuracy (Tuned Logistic Regression): {accuracy_best_logreg}")
print(f"Precision (Tuned Logistic Regression): {precision_best_logreg}")
print(f"Recall (Tuned Logistic Regression): {recall_best_logreg}")
print(f"F1-score (Tuned Logistic Regression): {f1_best_logreg}")
print(f"AUC-ROC (Tuned Logistic Regression): {auc_roc_best_logreg}")

# Generate confusion matrix for the best Logistic Regression model
cm_best_logreg = confusion_matrix(y_test, best_pred_logreg)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_best_logreg, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Tuned Logistic Regression)")
plt.show()

print(classification_report(y_test, best_pred_logreg))
# Out:
# Accuracy (Tuned Logistic Regression): 0.9766081871345029
# Precision (Tuned Logistic Regression): 0.9538461538461539
# Recall (Tuned Logistic Regression): 0.9841269841269841
# F1-score (Tuned Logistic Regression): 0.96875
# AUC-ROC (Tuned Logistic Regression): 0.9781746031746033
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       108
#            1       0.95      0.98      0.97        63
#
#     accuracy                           0.98       171
#    macro avg       0.97      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# TUNED AND DEFAULT MODELS COMPARISON

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Make sure X_test columns are strings if necessary, as done before
X_test.columns = X_test.columns.astype(str)

y_pred_svm = svm_classifier.predict(X_test)
y_pred_logreg = logreg_classifier.predict(X_test)

# Calculate metrics for each model
comp_metrics = {}


# SVM(TUNED) Metrics

comp_metrics['SVM(TUNED)'] = {
    'Accuracy': accuracy_best_svm,
    'Precision': precision_best_svm,
    'Recall': recall_best_svm,
    'F1-score': f1_best_svm,
    'AUC-ROC': auc_roc_best_svm
}

#Logistic Regression(TUNED) Metrics
comp_metrics['Logistic Regression(TUNED)'] = {
    'Accuracy': accuracy_best_logreg,
    'Precision': precision_best_logreg,
    'Recall': recall_best_logreg,
    'F1-score': f1_best_logreg,
    'AUC-ROC': auc_roc_best_logreg
}



metrics = {}
# SVM Metrics
metrics['SVM'] = {
    'Accuracy': accuracy_score(y_test, y_pred_svm),
    'Precision': precision_score(y_test, y_pred_svm),
    'Recall': recall_score(y_test, y_pred_svm),
    'F1-score': f1_score(y_test, y_pred_svm),
    'AUC-ROC': roc_auc_score(y_test, y_pred_svm)
}

# Logistic Regression Metrics
metrics['Logistic Regression'] = {
    'Accuracy': accuracy_score(y_test, y_pred_logreg),
    'Precision': precision_score(y_test, y_pred_logreg),
    'Recall': recall_score(y_test, y_pred_logreg),
    'F1-score': f1_score(y_test, y_pred_logreg),
    'AUC-ROC': roc_auc_score(y_test, y_pred_logreg)
}

# Combine the two comparison tables
metrics_df = pd.DataFrame(metrics).T
comp_metrics_df = pd.DataFrame(comp_metrics).T

all_metrics_df = pd.concat([metrics_df, comp_metrics_df])


# Display the combined table
print("\nTuned and Default Model Performance Comparison:")
display(all_metrics_df)
# Out:
# Tuned and Default Model Performance Comparison:
#                             Accuracy  Precision    Recall  F1-score   AUC-ROC
# SVM                         0.976608   0.968254  0.968254  0.968254  0.974868
# Logistic Regression         0.994152   1.000000  0.984127  0.992000  0.992063
# SVM(TUNED)                  0.994152   1.000000  0.984127  0.992000  0.992063
# Logistic Regression(TUNED)  0.976608   0.953846  0.984127  0.968750  0.978175
